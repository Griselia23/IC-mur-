# %% [markdown]
# # Import Library

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import os
import urllib.request
import zipfile

from PIL import Image
import io

from tensorflow.keras import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense

# %% [markdown]
# # Download and Save Dataset

# %%
url = 'https://github.com/Griselia23/IC-mur-/archive/refs/heads/main.zip'
#https://github.com/Griselia23/autocounterinko/archive/refs/heads/main.zip

zip_path = 'dataset-resized.zip'
extract_path = 'dataset-resized'

# Download the dataset zip file
urllib.request.urlretrieve(url, zip_path)

# Unzip the downloaded file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# Define the new data directory after extraction
data_dir = os.path.join(extract_path, 'IC-mur--main/dataset')

# %% [markdown]
# # Create Data Path

# %%
# Create a list of filepaths and labels
filepaths = []
labels = []
classlist = os.listdir(data_dir)
for kelass in classlist:
    classpath = os.path.join(data_dir, kelass)
    if os.path.isdir(classpath):
        flist = os.listdir(classpath)
        for f in flist:
            fpath = os.path.join(classpath, f)
            filepaths.append(fpath)
            labels.append(kelass)

# Create a DataFrame
Fseries = pd.Series(filepaths, name='filepaths')
Lseries = pd.Series(labels, name='labels')
df = pd.concat([Fseries, Lseries], axis=1)

print(df.head())
print(df['labels'].value_counts())
# Out:
#                                           filepaths labels
# 0  dataset-resized/IC-mur--main/dataset/m10/1 2.jpg    m10
# 1  dataset-resized/IC-mur--main/dataset/m10/1 5.jpg    m10
# 2  dataset-resized/IC-mur--main/dataset/m10/1 8.jpg    m10
# 3  dataset-resized/IC-mur--main/dataset/m10/1 3.jpg    m10
# 4  dataset-resized/IC-mur--main/dataset/m10/1 6.jpg    m10
# labels
# m10    13
# m8     13
# Name: count, dtype: int64

# %% [markdown]
# # Data Split

# %%
# Splitting data into train, validation, and test sets
train_split = .8
test_split = .1
dummy_split = test_split / (1 - train_split)
train_df, dummy_df = train_test_split(df, train_size=train_split, shuffle=True, random_state=123)
test_df, valid_df = train_test_split(dummy_df, train_size=dummy_split, shuffle=True, random_state=123)
print('train_df length:', len(train_df), 'test_df length:', len(test_df), 'valid_df length:', len(valid_df))
# Out:
# train_df length: 20 test_df length: 3 valid_df length: 3

# %% [markdown]
# # Preprocessing

# %%
# Preprocessing dataset
height = 224
width = 224
channels = 3
batch_size = 64
img_shape = (height, width, channels)
img_size = (height, width)

length = len(test_df)
test_batch_size = sorted([int(length/n) for n in range(1, length+1) if length % n == 0 and length/n <= 80], reverse=True)[0]
test_steps = int(length/test_batch_size)
print('test batch size:', test_batch_size, 'test steps:', test_steps)
# Out:
# test batch size: 3 test steps: 1

# %% [markdown]
# ## Augmentation

# %%
#augmentation
gen = ImageDataGenerator(rescale=1./255, rotation_range=15, zoom_range=0.2, horizontal_flip=True, fill_mode='nearest')
train_gen = gen.flow_from_dataframe(train_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical', color_mode='rgb', shuffle=True, batch_size=batch_size)
validgen = ImageDataGenerator(rescale=1./255)
valid_gen = validgen.flow_from_dataframe(valid_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical', color_mode='rgb', shuffle=True, batch_size=batch_size)
testgen = ImageDataGenerator(rescale=1./255)
test_gen = testgen.flow_from_dataframe(test_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical', color_mode='rgb', shuffle=False, batch_size=test_batch_size)
classes = list(train_gen.class_indices.keys())
print(classes)
class_count = len(classes)
# Out:
# Found 20 validated image filenames belonging to 2 classes.
# Found 3 validated image filenames belonging to 2 classes.
# Found 3 validated image filenames belonging to 2 classes.
# ['m10', 'm8']

# %%
# Image augmentation
gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=15,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)

# %% [markdown]
# ## Generate Data

# %%
#buat generator untuk train, valid, test
train_gen = gen.flow_from_dataframe(train_df, x_col='filepaths', y_col='labels',
                                    target_size=img_size, class_mode='categorical',
                                    color_mode='rgb', shuffle=True, batch_size=batch_size)
validgen = ImageDataGenerator(rescale=1./255)
valid_gen = validgen.flow_from_dataframe(valid_df, x_col='filepaths', y_col='labels',
                                         target_size=img_size, class_mode='categorical',
                                         color_mode='rgb', shuffle=True, batch_size=batch_size)
testgen = ImageDataGenerator(rescale=1./255)
test_gen = testgen.flow_from_dataframe(test_df, x_col='filepaths', y_col='labels',
                                       target_size=img_size, class_mode='categorical',
                                       color_mode='rgb', shuffle=False, batch_size=test_batch_size)
# Out:
# Found 20 validated image filenames belonging to 2 classes.
# Found 3 validated image filenames belonging to 2 classes.
# Found 3 validated image filenames belonging to 2 classes.

# %% [markdown]
# ## Data Checking

# %%
# Visualizing some sample images
def show_image_samples(gen):
    images, labels = next(gen)
    plt.figure(figsize=(20, 20))
    for i in range(min(len(labels), 25)):
        plt.subplot(5, 5, i + 1)
        plt.imshow(images[i])
        index = np.argmax(labels[i])
        class_name = classes[index]
        plt.title(class_name, color='blue', fontsize=16)
        plt.axis('off')
    plt.show()

show_image_samples(train_gen)

# %% [markdown]
# # Modeling

# %%
# Definisiin extractor dan compile model
base_model = MobileNetV2(include_top=False, weights="imagenet", input_shape=(224, 224, 3))
base_model.trainable = False
extractor = Model(inputs=base_model.input, outputs=base_model.get_layer('block_15_project_BN').output)

# Build the model
model = Sequential([
    extractor,  # Feature extractor
    Conv2D(filters=32, padding='same', kernel_size=3, activation='relu'),
    MaxPooling2D(pool_size=2, strides=2),
    Conv2D(filters=64, padding='same', kernel_size=3, activation='relu'),
    MaxPooling2D(pool_size=2, strides=2),
    Dropout(rate=0.5),
    Flatten(),
    Dense(len(classes), activation='softmax')
])

# Compile the model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Call build() method to build the model
model.build((None, 224, 224, 3))

# Print model summary
model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ functional_23 (Functional)           │ (None, 7, 7, 160)           │       1,364,864 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_10 (Conv2D)                   │ (None, 7, 7, 32)            │          46,112 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_10 (MaxPooling2D)      │ (None, 3, 3, 32)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_11 (Conv2D)                   │ (None, 3, 3, 64)            │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_11 (MaxPooling2D)      │ (None, 1, 1, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 1, 1, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_5 (Flatten)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 2)                   │             130 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,429,602 (5.45 MB)
#  Trainable params: 64,738 (252.88 KB)
#  Non-trainable params: 1,364,864 (5.21 MB)

# %% [markdown]
# # Training

# %%
# Training the model
early_stopping = EarlyStopping(monitor='val_loss', patience=5)
checkpoint = ModelCheckpoint('best_model.keras', monitor='val_loss', save_best_only=True)

history = model.fit(train_gen, epochs=20, validation_data=valid_gen, callbacks=[early_stopping, checkpoint])
# Out:
# Epoch 1/20
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator at 0x7fad77482830> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - accuracy: 0.5000 - loss: 3.9891 - val_accuracy: 0.0000e+00 - val_loss: 3.6735
# Epoch 2/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.6000 - loss: 1.7849 - val_accuracy: 0.3333 - val_loss: 5.0413
# Epoch 3/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.5000 - loss: 2.9486 - val_accuracy: 0.0000e+00 - val_loss: 3.2182
# Epoch 4/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.6500 - loss: 1.4580 - val_accuracy: 0.0000e+00 - val_loss: 1.5031
# Epoch 5/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.7000 - loss: 1.3166 - val_accuracy: 0.6667 - val_loss: 0.9826
# Epoch 6/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.6500 - loss: 1.1350 - val_accuracy: 0.6667 - val_loss: 0.7472
# Epoch 7/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8000 - loss: 0.7713 - val_accuracy: 0.6667 - val_loss: 0.7203
# Epoch 8/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.5500 - loss: 1.6296 - val_accuracy: 0.0000e+00 - val_loss: 0.8823
# Epoch 9/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.7000 - loss: 0.9466 - val_accuracy: 0.6667 - val_loss: 0.6989
# Epoch 10/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.6000 - loss: 1.5972 - val_accuracy: 0.6667 - val_loss: 0.5830
# Epoch 11/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.4500 - loss: 2.2194 - val_accuracy: 0.6667 - val_loss: 0.4938
# Epoch 12/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.7500 - loss: 0.7688 - val_accuracy: 0.6667 - val_loss: 0.4522
# Epoch 13/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.6500 - loss: 0.7901 - val_accuracy: 0.6667 - val_loss: 0.3942
# Epoch 14/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.5500 - loss: 0.8621 - val_accuracy: 1.0000 - val_loss: 0.3277
# Epoch 15/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.7000 - loss: 0.6126 - val_accuracy: 1.0000 - val_loss: 0.2602
# Epoch 16/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.6000 - loss: 0.6136 - val_accuracy: 1.0000 - val_loss: 0.2310
# Epoch 17/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8000 - loss: 0.3904 - val_accuracy: 1.0000 - val_loss: 0.2325
# Epoch 18/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.7000 - loss: 0.7171 - val_accuracy: 1.0000 - val_loss: 0.2547
# Epoch 19/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.8500 - loss: 0.4732 - val_accuracy: 1.0000 - val_loss: 0.2778
# Epoch 20/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.7500 - loss: 0.3212 - val_accuracy: 1.0000 - val_loss: 0.3034

# %%
# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss', color='blue', linestyle='-')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange', linestyle='--')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# Plot training and validation accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy', color='green', linestyle='-')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', color='red', linestyle='--')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Save and Convert Model

# %%
model.save('my_model.keras')
model.save('my_model.h5')
model = tf.keras.models.load_model('my_model.h5')
model.save('model_v1.5.h5')

converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

with open('model.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Saved artifact at '/tmp/tmpzaeligi4'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer_11')
# Output Type:
#   TensorSpec(shape=(None, 2), dtype=tf.float32, name=None)
# Captures:
#   140383120015424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120026864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120028976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120022288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120024576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120030384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120326720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120327600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120031264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120327072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120331472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120330768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120333056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120329712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120331120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120335344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120335696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120336928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120332000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120334992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120339568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120339920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120341328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120337808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120339216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120340096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120228416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120229296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120342560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120228768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120341856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120232288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120234576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120231232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120232640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120237040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120237392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120238624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120235280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120236688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120241088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120241440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120242848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120239328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120240736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120241616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120000448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383119999920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120244080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383119999744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120003792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120003088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120005376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120002032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120003440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120007840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120008192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120009424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120006080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120007488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120011712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120012064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120013472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120008368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120011360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120012240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120901568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120901040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120014704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120900864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120006784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120912128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120913184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120908960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120911072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120907904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120641008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120640656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120639952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120641536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120645056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120644176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120646640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120641888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120644704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120649104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120649456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120650864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120647344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120648752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120653152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120646992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120651216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120651040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120654032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120651744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120361952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120364240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120360720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120362304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120366704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120367056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120368288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120364944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120366352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120370576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120907376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120907024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120367232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120370224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120000976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120020528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120911600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120900336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120124640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120904384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120371984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120368640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120022112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120371280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120021936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120370928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120373920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120365120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120370400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120372864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120883776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120884656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120375328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120884128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120888528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120887824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120890112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120886768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120888176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120892576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120892928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120894160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120890816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120892224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120896624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120896976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120898384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120894864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120896272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120897152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121375296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121376176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383120899616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121375648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121380048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121379344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121381632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121378288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121379696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121384096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121384448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121385680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121382336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121383744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121388144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121388496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121389904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121386384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121387792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121390256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121638848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121638320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121390960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121638144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121388848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121641312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121643600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121639200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121641664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121646064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121646416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121647648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121644304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121645712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121650112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121650464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121651872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121648352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121649760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121650640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121065408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121064880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121653104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121064704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121648176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121067872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121070160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121065760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121068224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121072624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121072976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121074208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121070864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121072272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121076848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121077200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121078608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121075088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121076496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121077376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121801280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121802160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121079840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121801632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121079136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121805152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121807440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121804096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121805504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121809904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121810256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121811488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121808144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121809552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121813952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121814304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121815712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121812192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121813600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121814480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121081792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121081264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121816944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121081088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121815184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121084256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121086544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121082144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121084608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121089008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121089360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121090592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121087248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121088656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383112949152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383112947920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383112953376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383126932112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383121095344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140383127212224: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %% [markdown]
# # Testing

# %%
from tensorflow.keras.preprocessing import image
classes = ["m8","m10" ]

# %%
def preprocess_image(img, img_size=(224, 224)):
    img = img.resize(img_size)
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = img_array / 255.0
    return img_array

# %%
# Function to predict the class of the image
def predict_image_class(model, img):
    img_array = preprocess_image(img)
    predictions = model.predict(img_array)
    predicted_class = np.argmax(predictions, axis=1)
    class_name = classes[predicted_class[0]]
    confidence = np.max(predictions) * 100
    return class_name, confidence

# %%
def display_prediction(img, class_name, confidence):
    plt.imshow(img)
    plt.title(f"Predicted: {class_name} ({confidence:.2f}%)")
    plt.axis('off')
    plt.show()

# %%
import ipywidgets as widgets
upload_widget = widgets.FileUpload(accept='image/*', multiple=False)

def on_upload_change(change):
    # Get the uploaded file
    file = next(iter(upload_widget.value.values()))
    content = file['content']

    # Open the image
    img = Image.open(io.BytesIO(content))
    class_name, confidence = predict_image_class(model, img)
    display_prediction(img, class_name, confidence)

# %%
upload_widget.observe(on_upload_change, names='value')

display(upload_widget)
# Out:
# FileUpload(value={}, accept='image/*', description='Upload')
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step

# %%
#evaluasi bismillah
test_gen.reset()
predictions = model.predict(test_gen, steps=test_steps, verbose=1)

predicted_classes = np.argmax(predictions, axis=1)
true_classes = test_gen.classes

report = classification_report(true_classes, predicted_classes, target_names=classes)
print(report)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#               precision    recall  f1-score   support
#
#          m10       0.50      0.50      0.50         2
#           m8       0.00      0.00      0.00         1
#
#     accuracy                           0.33         3
#    macro avg       0.25      0.25      0.25         3
# weighted avg       0.33      0.33      0.33         3
